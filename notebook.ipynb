# %%
import flor

records = flor.log_records()
pivot = flor.full_pivot(records)
pivot.head()
# Out:
#                              projid  runid               tstamp  \
# 0  xp-tapas-base_flor.shadow.sigmod  BATCH  2023-06-20T15:05:35
# 1  xp-tapas-base_flor.shadow.sigmod  BATCH  2023-06-20T15:05:35
# 2  xp-tapas-base_flor.shadow.sigmod  BATCH  2023-06-20T15:05:35
# 3  xp-tapas-base_flor.shadow.sigmod  BATCH  2023-06-20T15:05:35
# 4  xp-tapas-base_flor.shadow.sigmod  BATCH  2023-06-20T15:05:35
#
#                                         vid  epoch  step                loss  \
# 0  26e6f6803c8425c203a0f4596600604ad0d9a798      1     1   1.393246054649353
# 1  26e6f6803c8425c203a0f4596600604ad0d9a798      1     2  1.5714781284332275
# 2  26e6f6803c8425c203a0f4596600604ad0d9a798      1     3  1.4488273859024048
# 3  26e6f6803c8425c203a0f4596600604ad0d9a798      1     4  1.4437848329544067
# 4  26e6f6803c8425c203a0f4596600604ad0d9a798      1     5   2.215627908706665
#
#   step_cap epochs batch_size weight_decay                      lr
# ...

# %%
flor.replay(
    apply_vars=['dp'], 
    where_clause=None, 
    path='train.py')
